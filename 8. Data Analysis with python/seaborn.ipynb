# %% [markdown]
# ## Seaborn
#
# Seaborn is a python visualisation library based on matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics. Seaborn helps in creating complex visualisations with just a few lines of code.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import ssl ## solution for error for ssl

ssl._create_default_https_context = ssl._create_stdlib_context

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
## create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("scatter plot of total plot of total bill vs tip")
# Out:
# Text(0.5, 1.0, 'scatter plot of total plot of total bill vs tip')

# %%
## line plot


sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("line plot of total plot bu bil size")
# Out:
# Text(0.5, 1.0, 'line plot of total plot bu bil size')
